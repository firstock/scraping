# %% [markdown]
# ### ref
# - [python list to dictionary](https://stackoverflow.com/questions/4576115/convert-a-list-to-a-dictionary-in-python?utm_medium=organic&utm_source=google_rich_qa&utm_campaign=google_rich_qa)

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('data/naverNewsSomePressLinks.csv', index_col=False, header=None)

# %%
len(df)
# Out:
# 3990

# %% [markdown]
# ### 긁으려는거 외 링크 지우기
# 133개 지움

# %%
exceptList= ['www.kukinews.com', 'news.kukinews.com', 'www.seouland.com', 'nownews.seoul.co', 'nownewstv.seoul.co', 'www.sporbiz.co', 'www.beautyhankook.com']

# %%
for exLink in exceptList:
    df= df[df[0].map(lambda x: (exLink not in x))]
df
# Out:
#                                                       0
# 0     http://www.newsis.com/view/?id=NISX20180421_00...
# 1     http://www.seoul.co.kr/news/newsView.php?id=20...
# 2     http://www.hankookilbo.com/v/0e2f312b60b84e099...
# 3     http://bizn.donga.com/realestate/3/all/2018041...
# 4          http://news.joins.com/article/olink/22127647
# 5          http://news.joins.com/article/olink/22120203
# 6     http://news.chosun.com/site/data/html_dir/2018...
# 7     http://app.yonhapnews.co.kr/YNA/Basic/SNS/r.as...
# 8     http://www.asiatoday.co.kr/view.php?key=201804...
# 9     http://www.asiatoday.co.kr/view.php?key=201804...
# 10    http://www.segye.com/content/html/2018/04/04/2...
# 11    http://www.newsis.com/view/?id=NISX20180404_00...
# 12    http://www.hani.co.kr/arti/economy/it/839062.html
# 13    http://app.yonhapnews.co.kr/YNA/Basic/SNS/r.as...
# 14    http://www.hankookilbo.com/v/913aae16ab494423a...
# 15    http://news.chosun.com/site/data/html_dir/2018...
# 16    http://app.yonhapnews.co.kr/YNA/Basic/SNS/r.as...
# 17    http://www.m-i.kr/news/articleView.html?idxno=...
# 18    http://www.asiatoday.co.kr/view.php?key=201803...
# 19    http://www.asiatoday.co.kr/view.php?key=201803...
# 20    http://app.yonhapnews.co.kr/YNA/Basic/SNS/r.as...
# 21    http://news.khan.co.kr/kh_news/khan_art_view.h...
# 22    http://app.yonhapnews.co.kr/YNA/Basic/SNS/r.as...
# 23      http://news.donga.com/3/all/20180419/89699544/1
# 24    http://www.segye.com/content/html/2018/03/15/2...
# 25    http://www.newsis.com/view/?id=NISX20180312_00...
# 26    http://www.newsis.com/view/?id=NISX20180307_00...
# 27    http://www.m-i.kr/news/articleView.html?idxno=...
# 28    http://www.asiatoday.co.kr/view.php?key=201803...
# 29    http://www.m-i.kr/news/articleView.html?idxno=...
# ...                                                 ...
# 3959  http://news.naver.com/main/read.nhn?mode=LSD&m...
# 3960  http://news.naver.com/main/read.nhn?mode=LSD&m...
# 3961  http://news.naver.com/main/read.nhn?mode=LSD&m...
# 3962  http://www.hani.co.kr/arti/society/ngo/715760....
# 3963  http://www.hani.co.kr/kisa/section-002008000/2...
# 3964  http://www.khan.co.kr/kh_news/art_view.html?ar...
# 3965  http://www.newsis.com/ar_detail/view.html?ar_i...
# 3966  http://www.newsis.com/ar_detail/view.html?ar_i...
# 3967  http://news.khan.co.kr/kh_news/khan_art_view.h...
# 3968  http://news.naver.com/main/read.nhn?mode=LSD&m...
# 3969  http://news.naver.com/main/read.nhn?mode=LSD&m...
# 3970  http://news.naver.com/main/read.nhn?mode=LSD&m...
# 3971  http://news.naver.com/main/read.nhn?mode=LSD&m...
# 3972  http://news.naver.com/main/read.nhn?mode=LSD&m...
# 3973  http://www.newsis.com/ar_detail/view.html?ar_i...
# 3974  http://www.segye.com/content/html/2015/11/24/2...
# 3975  http://www.newsis.com/ar_detail/view.html?ar_i...
# 3976  http://news.naver.com/main/read.nhn?mode=LSD&m...
# 3977  http://www.hankookilbo.com/v/b3790ec97a9a499b8...
# 3978  http://app.yonhapnews.co.kr/YNA/Basic/SNS/r.as...
# 3979  http://www.asiatoday.co.kr/view.php?key=201602...
# 3980  http://app.yonhapnews.co.kr/YNA/Basic/SNS/r.as...
# 3981  http://news.naver.com/main/read.nhn?mode=LSD&m...
# 3982  http://www.newsis.com/ar_detail/view.html?ar_i...
# 3983  http://www.newsis.com/ar_detail/view.html?ar_i...
# 3984  http://www.newsis.com/ar_detail/view.html?ar_i...
# 3985  http://www.hankookilbo.com/v/4ad194d2c2214637b...
# 3986  http://www.segye.com/content/html/2016/02/21/2...
# 3987  http://news.naver.com/main/read.nhn?mode=LSD&m...
# 3989  http://www.asiatoday.co.kr/view.php?key=201602...
#
# [3857 rows x 1 columns]

# %%
len(df)
# Out:
# 3857

# %%
df[0].map(lambda x: (exceptList[0] in x)).sum()
# Out:
# 0

# %% [markdown]
# ### dict만들기
# key: http빼고 사이트 앞 3어절, value: XPATH

# %%
link= ['news.khan.co', 'www.khan.co', 'h2.khan.co', 'news.kmib.co', 'www.naeil.com', 'news.donga.com', 'www.donga.com', 'realestate.donga.com', 'bizn.donga.com', 'travel.donga.com', 'studio.donga.com', 'yachtpia.donga.com', 'it.donga.com', 'www.m-i.kr', 'www.munhwa.com', 'www.seoul.co', 'ntn.seoul.co', 'stv.seoul.co', 'www.segye.com', 'local.segye.com', 'www.segyefn.com', 'economysegye.segye.com', 'fn.segye.com', 'www.asiatoday.co', 'news.chosun.com', 'biz.chosun.com', 'car.chosun.com', 'life.chosun.com', 'businessnews.chosun.com', 'news.joins.com', 'realestate.joins.com', 'www.hani.co', 'babytree.hani.co', '2korea.hani.co', 'www.hankookilbo.com', 'www.newsis.com', 'sports.news.naver', 'news.naver.com', 'app.yonhapnews.co', 'www.wowtv.co', 'www.wownet.co', 'news.wowtv.co', 'sports.wowtv.co', 'wowstar.wowtv.co', 'news.jtbc.co', 'www.sisain.co', 'www.sisainlive.com']

# %%
dupCnt= [3,1,1,8,1,1,3,5,1,5,2,3,1,2,2,5,1,2]

# %%
xpaths= ['//div[@id="articleBody"]', '//div[@id="articleBody"]', '//div[@class="articleArea"]', '//div[@id="ct"]', '//div[@class="content"]', '//div[@id="NewsAdContent"]', '//div[@id="article_content"]', '//div[@id="article_txt"]', '//div[@id="font"]', '//div[@id="news_body_id"]/div[@class="par"]', '//div[@id="article_body"]', '//div[@class="article-text-font-size"]', '//article[@id="article-body"]', '//div[@id="#textBody"]', '//div[@id="articleWrap"]', '//div[@id="divNewsContent"]', '//div[@class="article_content"]', '//div[@itemprop="articleBody"]']
xpaths= np.array(xpaths)

# %%
print(len(xpaths))
print(len(dupCnt))
# Out:
# 18
# 18

# %%
xpaths_s= list(xpaths.repeat(dupCnt))
xpaths_s
# Out:
# ['//div[@id="articleBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@class="articleArea"]',
#  '//div[@id="ct"]',
#  '//div[@id="ct"]',
#  '//div[@id="ct"]',
#  '//div[@id="ct"]',
#  '//div[@id="ct"]',
#  '//div[@id="ct"]',
#  '//div[@id="ct"]',
#  '//div[@id="ct"]',
#  '//div[@class="content"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="article_content"]',
#  '//div[@id="article_content"]',
#  '//div[@id="article_content"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="font"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="article_body"]',
#  '//div[@id="article_body"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@class="article-text-font-size"]',
#  '//article[@id="article-body"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="divNewsContent"]',
#  '//div[@id="divNewsContent"]',
#  '//div[@id="divNewsContent"]',
#  '//div[@id="divNewsContent"]',
#  '//div[@id="divNewsContent"]',
#  '//div[@class="article_content"]',
#  '//div[@itemprop="articleBody"]',
#  '//div[@itemprop="articleBody"]']

# %%
print(link)
print(xpaths_s)
# Out:
# ['news.khan.co', 'www.khan.co', 'h2.khan.co', 'news.kmib.co', 'www.naeil.com', 'news.donga.com', 'www.donga.com', 'realestate.donga.com', 'bizn.donga.com', 'travel.donga.com', 'studio.donga.com', 'yachtpia.donga.com', 'it.donga.com', 'www.m-i.kr', 'www.munhwa.com', 'www.seoul.co', 'ntn.seoul.co', 'stv.seoul.co', 'www.segye.com', 'local.segye.com', 'www.segyefn.com', 'economysegye.segye.com', 'fn.segye.com', 'www.asiatoday.co', 'news.chosun.com', 'biz.chosun.com', 'car.chosun.com', 'life.chosun.com', 'businessnews.chosun.com', 'news.joins.com', 'realestate.joins.com', 'www.hani.co', 'babytree.hani.co', '2korea.hani.co', 'www.hankookilbo.com', 'www.newsis.com', 'sports.news.naver', 'news.naver.com', 'app.yonhapnews.co', 'www.wowtv.co', 'www.wownet.co', 'news.wowtv.co', 'sports.wowtv.co', 'wowstar.wowtv.co', 'news.jtbc.co', 'www.sisain.co', 'www.sisainlive.com']
# ['//div[@id="articleBody"]', '//div[@id="articleBody"]', '//div[@id="articleBody"]', '//div[@id="articleBody"]', '//div[@class="articleArea"]', '//div[@id="ct"]', '//div[@id="ct"]', '//div[@id="ct"]', '//div[@id="ct"]', '//div[@id="ct"]', '//div[@id="ct"]', '//div[@id="ct"]', '//div[@id="ct"]', '//div[@class="content"]', '//div[@id="NewsAdContent"]', '//div[@id="article_content"]', '//div[@id="article_content"]', '//div[@id="article_content"]', '//div[@id="article_txt"]', '//div[@id="article_txt"]', '//div[@id="article_txt"]', '//div[@id="article_txt"]', '//div[@id="article_txt"]', '//div[@id="font"]', '//div[@id="news_body_id"]/div[@class="par"]', '//div[@id="news_body_id"]/div[@class="par"]', '//div[@id="news_body_id"]/div[@class="par"]', '//div[@id="news_body_id"]/div[@class="par"]', '//div[@id="news_body_id"]/div[@class="par"]', '//div[@id="article_body"]', '//div[@id="article_body"]', '//div[@class="article-text-font-size"]', '//div[@class="article-text-font-size"]', '//div[@class="article-text-font-size"]', '//article[@id="article-body"]', '//div[@id="#textBody"]', '//div[@id="#textBody"]', '//div[@id="articleWrap"]', '//div[@id="articleWrap"]', '//div[@id="divNewsContent"]', '//div[@id="divNewsContent"]', '//div[@id="divNewsContent"]', '//div[@id="divNewsContent"]', '//div[@id="divNewsContent"]', '//div[@class="article_content"]', '//div[@itemprop="articleBody"]', '//div[@itemprop="articleBody"]']

# %%
dictLink= dict(zip(link,xpaths_s))
dictLink
# Out:
# {'2korea.hani.co': '//div[@class="article-text-font-size"]',
#  'app.yonhapnews.co': '//div[@id="articleWrap"]',
#  'babytree.hani.co': '//div[@class="article-text-font-size"]',
#  'biz.chosun.com': '//div[@id="news_body_id"]/div[@class="par"]',
#  'bizn.donga.com': '//div[@id="ct"]',
#  'businessnews.chosun.com': '//div[@id="news_body_id"]/div[@class="par"]',
#  'car.chosun.com': '//div[@id="news_body_id"]/div[@class="par"]',
#  'economysegye.segye.com': '//div[@id="article_txt"]',
#  'fn.segye.com': '//div[@id="article_txt"]',
#  'h2.khan.co': '//div[@id="articleBody"]',
#  'it.donga.com': '//div[@id="ct"]',
#  'life.chosun.com': '//div[@id="news_body_id"]/div[@class="par"]',
#  'local.segye.com': '//div[@id="article_txt"]',
#  'news.chosun.com': '//div[@id="news_body_id"]/div[@class="par"]',
#  'news.donga.com': '//div[@id="ct"]',
#  'news.joins.com': '//div[@id="article_body"]',
#  'news.jtbc.co': '//div[@class="article_content"]',
#  'news.khan.co': '//div[@id="articleBody"]',
#  'news.kmib.co': '//div[@id="articleBody"]',
#  'news.naver.com': '//div[@id="articleWrap"]',
#  'news.wowtv.co': '//div[@id="divNewsContent"]',
#  'ntn.seoul.co': '//div[@id="article_content"]',
#  'realestate.donga.com': '//div[@id="ct"]',
#  'realestate.joins.com': '//div[@id="article_body"]',
#  'sports.news.naver': '//div[@id="#textBody"]',
#  'sports.wowtv.co': '//div[@id="divNewsContent"]',
#  'studio.donga.com': '//div[@id="ct"]',
#  'stv.seoul.co': '//div[@id="article_content"]',
#  'travel.donga.com': '//div[@id="ct"]',
#  'wowstar.wowtv.co': '//div[@id="divNewsContent"]',
#  'www.asiatoday.co': '//div[@id="font"]',
#  'www.donga.com': '//div[@id="ct"]',
#  'www.hani.co': '//div[@class="article-text-font-size"]',
#  'www.hankookilbo.com': '//article[@id="article-body"]',
#  'www.khan.co': '//div[@id="articleBody"]',
#  'www.m-i.kr': '//div[@class="content"]',
#  'www.munhwa.com': '//div[@id="NewsAdContent"]',
#  'www.naeil.com': '//div[@class="articleArea"]',
#  'www.newsis.com': '//div[@id="#textBody"]',
#  'www.segye.com': '//div[@id="article_txt"]',
#  'www.segyefn.com': '//div[@id="article_txt"]',
#  'www.seoul.co': '//div[@id="article_content"]',
#  'www.sisain.co': '//div[@itemprop="articleBody"]',
#  'www.sisainlive.com': '//div[@itemprop="articleBody"]',
#  'www.wownet.co': '//div[@id="divNewsContent"]',
#  'www.wowtv.co': '//div[@id="divNewsContent"]',
#  'yachtpia.donga.com': '//div[@id="ct"]'}

# %% [markdown]
# ### xpath 얻기

# %%
sriLink= df[0].map(lambda x: '.'.join(x.split('/')[2].split('.')[0:3]))
sriLink
# Out:
# 0            www.newsis.com
# 1              www.seoul.co
# 2       www.hankookilbo.com
# 3            bizn.donga.com
# 4            news.joins.com
# 5            news.joins.com
# 6           news.chosun.com
# 7         app.yonhapnews.co
# 8          www.asiatoday.co
# 9          www.asiatoday.co
# 10            www.segye.com
# 11           www.newsis.com
# 12              www.hani.co
# 13        app.yonhapnews.co
# 14      www.hankookilbo.com
# 15          news.chosun.com
# 16        app.yonhapnews.co
# 17               www.m-i.kr
# 18         www.asiatoday.co
# 19         www.asiatoday.co
# 20        app.yonhapnews.co
# 21             news.khan.co
# 22        app.yonhapnews.co
# 23           news.donga.com
# 24            www.segye.com
# 25           www.newsis.com
# 26           www.newsis.com
# 27               www.m-i.kr
# 28         www.asiatoday.co
# 29               www.m-i.kr
#                ...
# 3959         news.naver.com
# 3960         news.naver.com
# 3961         news.naver.com
# 3962            www.hani.co
# 3963            www.hani.co
# 3964            www.khan.co
# 3965         www.newsis.com
# 3966         www.newsis.com
# 3967           news.khan.co
# 3968         news.naver.com
# 3969         news.naver.com
# 3970         news.naver.com
# 3971         news.naver.com
# 3972         news.naver.com
# 3973         www.newsis.com
# 3974          www.segye.com
# 3975         www.newsis.com
# 3976         news.naver.com
# 3977    www.hankookilbo.com
# 3978      app.yonhapnews.co
# 3979       www.asiatoday.co
# 3980      app.yonhapnews.co
# 3981         news.naver.com
# 3982         www.newsis.com
# 3983         www.newsis.com
# 3984         www.newsis.com
# 3985    www.hankookilbo.com
# 3986          www.segye.com
# 3987         news.naver.com
# 3989       www.asiatoday.co
# Name: 0, Length: 3857, dtype: object

# %%
sriLink.value_counts()
# Out:
# news.naver.com             928
# www.newsis.com             549
# app.yonhapnews.co          473
# www.asiatoday.co           224
# www.seoul.co               206
# www.segye.com              168
# www.m-i.kr                 158
# news.donga.com             149
# www.hankookilbo.com        130
# news.khan.co               124
# www.hani.co                123
# www.munhwa.com              89
# www.khan.co                 85
# news.kmib.co                84
# www.naeil.com               72
# news.joins.com              71
# www.wowtv.co                45
# www.donga.com               36
# news.chosun.com             27
# news.jtbc.co                25
# realestate.donga.com        16
# bizn.donga.com               9
# local.segye.com              8
# www.wownet.co                7
# www.sisain.co                6
# news.wowtv.co                6
# travel.donga.com             3
# www.sisainlive.com           3
# biz.chosun.com               3
# sports.news.naver            3
# www.segyefn.com              3
# h2.khan.co                   3
# sports.wowtv.co              2
# fn.segye.com                 2
# babytree.hani.co             2
# realestate.joins.com         2
# economysegye.segye.com       2
# studio.donga.com             2
# yachtpia.donga.com           1
# car.chosun.com               1
# wowstar.wowtv.co             1
# stv.seoul.co                 1
# it.donga.com                 1
# life.chosun.com              1
# businessnews.chosun.com      1
# 2korea.hani.co               1
# ntn.seoul.co                 1
# Name: 0, dtype: int64

# %%
xpathList= list([])
for link in sriLink:
    xpathList.append(dictLink[link])
xpathList
# Out:
# ['//div[@id="#textBody"]',
#  '//div[@id="article_content"]',
#  '//article[@id="article-body"]',
#  '//div[@id="ct"]',
#  '//div[@id="article_body"]',
#  '//div[@id="article_body"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="articleWrap"]',
#  '//article[@id="article-body"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="ct"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//article[@id="article-body"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="articleArea"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="ct"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="article_body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="font"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="ct"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_body"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleBody"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="font"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleBody"]',
#  '//div[@class="articleArea"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_txt"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_content"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_body"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleBody"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="font"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="articleArea"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="articleArea"]',
#  '//div[@id="article_txt"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_content"]',
#  '//article[@id="article-body"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="article_body"]',
#  '//article[@id="article-body"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="ct"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="article_txt"]',
#  '//div[@class="article_content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="#textBody"]',
#  '//article[@id="article-body"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="ct"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_body"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_body"]',
#  '//div[@id="articleBody"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_content"]',
#  '//div[@id="font"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_content"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="divNewsContent"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@id="divNewsContent"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_content"]',
#  '//article[@id="article-body"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_txt"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_txt"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="ct"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="content"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//article[@id="article-body"]',
#  '//div[@class="article_content"]',
#  '//div[@id="font"]',
#  '//div[@class="articleArea"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_body"]',
#  '//div[@id="article_body"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_body"]',
#  '//div[@id="article_body"]',
#  '//div[@id="articleWrap"]',
#  '//article[@id="article-body"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleWrap"]',
#  '//article[@id="article-body"]',
#  '//article[@id="article-body"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//article[@id="article-body"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_txt"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_txt"]',
#  '//article[@id="article-body"]',
#  '//div[@id="ct"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="article_txt"]',
#  '//div[@class="article_content"]',
#  '//article[@id="article-body"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="#textBody"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_content"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="articleArea"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_body"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_body"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="font"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_body"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@class="content"]',
#  '//div[@class="articleArea"]',
#  '//div[@class="content"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_body"]',
#  '//article[@id="article-body"]',
#  '//div[@id="font"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="divNewsContent"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="ct"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="article_body"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="article_content"]',
#  '//div[@id="article_content"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@class="articleArea"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="article_content"]',
#  '//div[@id="article_content"]',
#  '//div[@id="article_body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="article_txt"]',
#  '//div[@class="articleArea"]',
#  '//div[@id="font"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="ct"]',
#  '//div[@id="ct"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="article_body"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//article[@id="article-body"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="articleArea"]',
#  '//div[@class="articleArea"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_body"]',
#  '//div[@class="article_content"]',
#  '//div[@id="divNewsContent"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="ct"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="font"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_body"]',
#  '//div[@id="articleWrap"]',
#  '//article[@id="article-body"]',
#  '//div[@id="article_body"]',
#  '//div[@class="article_content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="ct"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="content"]',
#  '//div[@id="article_content"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_body"]',
#  '//div[@id="article_body"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@class="articleArea"]',
#  '//div[@class="content"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_txt"]',
#  '//div[@itemprop="articleBody"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@class="articleArea"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@class="article-text-font-size"]',
#  '//article[@id="article-body"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_body"]',
#  '//div[@class="articleArea"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_body"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="ct"]',
#  '//div[@id="article_content"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_content"]',
#  '//div[@id="article_content"]',
#  '//div[@id="article_body"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="article_txt"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="articleBody"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//article[@id="article-body"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_txt"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="article_txt"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_content"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="ct"]',
#  '//div[@class="content"]',
#  '//div[@id="ct"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@class="articleArea"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="ct"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//article[@id="article-body"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="font"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="font"]',
#  '//div[@class="articleArea"]',
#  '//div[@class="content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="divNewsContent"]',
#  '//div[@id="articleWrap"]',
#  '//article[@id="article-body"]',
#  '//div[@class="article_content"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@class="article_content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_content"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_body"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="article_body"]',
#  '//div[@id="article_body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="divNewsContent"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="article_content"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_txt"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="article_body"]',
#  '//div[@id="article_body"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="article_content"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="article_content"]',
#  '//div[@class="article_content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//article[@id="article-body"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@class="articleArea"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@class="content"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="article_body"]',
#  '//div[@id="article_body"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleBody"]',
#  '//article[@id="article-body"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="font"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="ct"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="articleArea"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="font"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_body"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@id="articleWrap"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="NewsAdContent"]',
#  '//article[@id="article-body"]',
#  '//div[@class="article_content"]',
#  '//div[@id="font"]',
#  '//div[@class="articleArea"]',
#  '//div[@class="article_content"]',
#  '//article[@id="article-body"]',
#  '//div[@id="article_body"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="article_content"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="ct"]',
#  '//div[@id="NewsAdContent"]',
#  '//article[@id="article-body"]',
#  '//div[@id="font"]',
#  '//div[@class="articleArea"]',
#  '//div[@class="articleArea"]',
#  '//article[@id="article-body"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_content"]',
#  '//div[@class="content"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleBody"]',
#  '//article[@id="article-body"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="articleBody"]',
#  '//article[@id="article-body"]',
#  '//div[@id="article_body"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="ct"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="article_content"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="article_content"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="article_content"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleBody"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="divNewsContent"]',
#  '//div[@id="font"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="divNewsContent"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleBody"]',
#  '//div[@itemprop="articleBody"]',
#  '//div[@id="article_body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="font"]',
#  '//div[@class="articleArea"]',
#  '//div[@class="content"]',
#  '//article[@id="article-body"]',
#  '//article[@id="article-body"]',
#  '//article[@id="article-body"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="content"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@class="content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@itemprop="articleBody"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_content"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="article_content"]',
#  '//div[@class="content"]',
#  '//div[@id="#textBody"]',
#  '//article[@id="article-body"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="article_content"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="ct"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@id="ct"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_content"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="font"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="article_content"]',
#  '//article[@id="article-body"]',
#  '//div[@id="news_body_id"]/div[@class="par"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@id="ct"]',
#  '//div[@id="article_txt"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="NewsAdContent"]',
#  '//div[@id="article_txt"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@class="content"]',
#  '//div[@id="font"]',
#  '//div[@class="content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_content"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="ct"]',
#  '//div[@id="font"]',
#  '//div[@id="ct"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_content"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_content"]',
#  '//div[@id="#textBody"]',
#  '//article[@id="article-body"]',
#  '//div[@id="#textBody"]',
#  '//div[@class="content"]',
#  '//div[@id="ct"]',
#  '//div[@id="article_body"]',
#  '//div[@id="articleWrap"]',
#  '//div[@id="article_content"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="articleWrap"]',
#  '//div[@class="article-text-font-size"]',
#  '//div[@id="#textBody"]',
#  '//div[@id="font"]',
#  ...]
